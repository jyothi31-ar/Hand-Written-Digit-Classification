# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
Y_train.shape
# Out:
# (60000,)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
Y_test.shape
# Out:
# (10000,)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
for i in range(0, 10):
    plt.imshow(X_train[i])
    plt.show()

# %%
Y_train[0:10]
# Out:
# array([5, 0, 4, 1, 9, 2, 1, 3, 1, 4], dtype=uint8)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 11s 5ms/step - loss: 2.6225 - accuracy: 0.6948
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.5625 - accuracy: 0.8448
# Epoch 3/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.4155 - accuracy: 0.8830
# Epoch 4/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3408 - accuracy: 0.9054
# Epoch 5/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3020 - accuracy: 0.9162
# Epoch 6/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2805 - accuracy: 0.9224
# Epoch 7/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2637 - accuracy: 0.9284
# Epoch 8/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2441 - accuracy: 0.9331
# Epoch 9/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2373 - accuracy: 0.9351
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2210 - accuracy: 0.9394

# %%
predictions = model.evaluate(X_test,  Y_test, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.1632 - accuracy: 0.9594 - 1s/epoch - 4ms/step

# %%
predictions
# Out:
# [0.16319267451763153, 0.9593999981880188]

# %%
model.predict(X_train[0].reshape(-1,28,28))
# Out:
# 1/1 [==============================] - 0s 50ms/step
# array([[ 55.84576 ,  56.76735 ,  46.18305 ,  87.02531 ,  50.244534,
#         106.62207 ,  70.043304,  23.822676,  67.82897 ,  79.19125 ]],
#       dtype=float32)

# %%
import numpy
x = numpy.random.rand(28, 28)

# %%
for i in range(0, 10):
    plt.imshow(X_test[i])
    plt.show()

# %%
model.predict(X_test[0].reshape(-1,28,28))
# Out:
# 1/1 [==============================] - 0s 37ms/step
# array([[-5.9013634, 34.333813 , 35.746635 , 38.20931  , 34.13116  ,
#         20.267128 , -7.9591637, 51.254055 , 23.897963 , 37.353962 ]],
#       dtype=float32)
